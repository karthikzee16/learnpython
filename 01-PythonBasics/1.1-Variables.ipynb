# %% [markdown]
# ### Variables
# Variables are fundamental elements in programming used to store data that can be referenced and manipulated in a program. <span style="color:red">In Python, variables are created when you assign a value to them, and they do not need explicit declaration to reserve memory space. The declaration happens automatically when you assign a value to a variable.</span>
#
#
#
#
# ![image.png](attachment:image.png)
# Python:
# - Creates an object 10 (an integer object)
# - Creates a name/reference x
# - Points x → to that object
#
# C#:
# - x has a fixed type (int)
# - Memory is reserved based on type
# - x holds the object directly
#
# https://chatgpt.com/s/t_69e1a64b71448191be5df86e2eef6b48
#
# https://chatgpt.com/s/t_69e1a85a417081918ad8fbc8aef28a87
#
# Video Outline:
# - Introduction to Variables
# - Declaring and Assigning Variables
# - Naming Conventions
# - Understanding Variable Types
# - Type Checking and Conversion
# - Dynamic Typing
# - Practical Examples and Common Errors

# %%
a=100

# %%
## Declaring And Assigning Variables

age=32
height=6.1
name="Krish"
is_student=True

## printing the variables

print("age :",age)
print("Height:",height)
print("Name:",name)
# Out:
# age : 32
# Height: 6.1
# Name: Krish

# %%
## Naming Conventions
## Variable names should be descriptive
## They must start with a letter or an '_' and can contain letter,numbers and underscores
## variables names are case sensitive

#valid variable names

first_name="KRish"
last_name="Naik"

# %%
# Invalid variable names
#2age=30
#first-name="Krish"
##@name="Krish"
# Out:
#   Cell In[6], line 4
#     @name="Krish"
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
## case sensitivity
name="Krish"
Name="Naik"
# Out:
# False

# %% [markdown]
# <span style="color:red"> Python is dynamically typed,type of a variable is determined at runtime</span>

# %%
## Understnading Variable types
## Python is dynamically typed,type of a variable is determined at runtime
age=25 #int
height=6.1 #float
name="KRish" #str
is_student=True #bool

print(type(name))
# Out:
# <class 'str'>

# %%
## Type Checking and Conversion

type(height)
# Out:
# float

# %%
age=25
print(type(age))

# Type conversion
age_str=str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 25
# <class 'str'>

# %%
age='25'
print(type(int(age)))
# Out:
# <class 'int'>

# %%
name="Krish"
int(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 name="Krish"
# ----> 2 int(name)
#
# ValueError: invalid literal for int() with base 10: 'Krish'

# %%
height=5.11
type(height)
# Out:
# float

# %%
float(int(height))
# Out:
# 5.0

# %%
## Dynamic Typing
## Python allows the type of a vraible to change as the program executes
var=10 #int
print(var,type(var))

var="Hello"
print(var,type(var))

var=3.14
print(var,type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>
# 3.14 <class 'float'>

# %%
## input

age=int(input("What is the age"))
print(age,type(age))
# Out:
# 23 <class 'int'>

# %%
### Simple calculator
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

sum = num1 + num2
difference = num1 - num2
product = num1 * num2
quotient = num1 / num2

print("Sum:", sum)
print("Difference:", difference)
print("Product:", product)
print("Quotient:", quotient)
# Out:
# Sum: 66.0
# Difference: 46.0
# Product: 560.0
# Quotient: 5.6

# %%
# Out:
# 23 <class 'int'>

# %% [markdown]
# ### Conclusion:
# Variables are essential in Python programming for storing and manipulating data. Understanding how to declare, assign, and use variables effectively is crucial for writing functional and efficient code. Following proper naming conventions and understanding variable types will help in maintaining readability and consistency in your code.
